# %%
import pandas as pd
import csv

# %%
happiness_report_multiyear = pd.read_csv(r"C:\Users\rabbi\Documents\VU_DataAnalytics_BootCamp\Project_Scrap\2021\world-happiness-report.csv")

# %%
happiness_report_multiyear.head()
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008        3.724               7.370           0.451
# 1  Afghanistan  2009        4.402               7.540           0.552
# 2  Afghanistan  2010        4.758               7.647           0.539
# 3  Afghanistan  2011        3.832               7.620           0.521
# 4  Afghanistan  2012        3.783               7.705           0.521
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                             50.80                         0.718       0.168
# 1                             51.20                         0.679       0.190
# 2                             51.60                         0.600       0.121
# 3                             51.92                         0.496       0.162
# 4                             52.24                         0.531       0.236
#
#    Perceptions of corruption  Positive affect  Negative affect
# ...

# %%
happiness_report_without_null = happiness_report_multiyear.dropna()

# %%
happiness_report_without_null.describe()
# Out:
#               year  Life Ladder  Log GDP per capita  Social support  \
# count  1708.000000  1708.000000         1708.000000     1708.000000
# mean   2013.289227     5.446680            9.321709        0.810321
# std       4.073657     1.136592            1.158344        0.121638
# min    2005.000000     2.375000            6.635000        0.290000
# 25%    2010.000000     4.595000            8.394000        0.741000
# 50%    2013.000000     5.364000            9.456500        0.835000
# 75%    2017.000000     6.259000           10.272000        0.908000
# max    2020.000000     7.971000           11.648000        0.987000
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                       1708.000000                   1708.000000
# mean                          63.225465                      0.739442
# std                            7.687011                      0.142846
# min                           32.300000                      0.258000
# ...

# %%
happiness_report_without_null.to_csv('happiness_report_multiyear_without_null.csv', index = False, encoding='utf-8')

# %%
print(happiness_report_without_null.isnull().sum().sum())
# Out:
# 0
